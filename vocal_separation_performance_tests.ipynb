# %%
import numpy as np
import librosa
# !pip install mir_eval
import mir_eval
from scipy.io import wavfile
import os



# Funcție pentru a alinia lungimile semnalelor audio
def match_length(reference, estimated):
    max_length = max(reference.shape[-1], estimated.shape[-1])
    if reference.shape[-1] < max_length:
        reference = np.pad(reference, [(0, 0), (0, max_length - reference.shape[-1])], mode='constant')
    if estimated.shape[-1] < max_length:
        estimated = np.pad(estimated, [(0, 0), (0, max_length - estimated.shape[-1])], mode='constant')
    return reference, estimated

# Încărcarea datelor
file_path = '/content/Kid CuDi Day N Nite.wav'
y, sr = librosa.load(file_path, duration=120)

# Setări pentru experimente
fft_sizes = [512, 1024, 2048]
overlaps = [0.25, 0.5]
margin_settings = [(1, 5), (2, 10), (3, 15)]
powers = [1, 2, 3]
results = []

# Bucle pentru fiecare combinație de setări
for fft_size in fft_sizes:
    for overlap in overlaps:
        for margins in margin_settings:
            for power in powers:
                hop_length = int(fft_size * overlap)
                S_full, phase = librosa.magphase(librosa.stft(y, n_fft=fft_size, hop_length=hop_length))
                margin_i, margin_v = margins

                # Filtrarea mediană și crearea măștilor
                S_filter = librosa.decompose.nn_filter(S_full, aggregate=np.median, metric='cosine', width=int(librosa.time_to_frames(2, sr=sr)))
                S_filter = np.minimum(S_full, S_filter)
                mask_i = librosa.util.softmask(S_filter, margin_i * (S_full - S_filter), power=power)
                mask_v = librosa.util.softmask(S_full - S_filter, margin_v * S_filter, power=power)

                # Separarea surselor
                S_background = mask_i * S_full
                S_foreground = mask_v * S_full
                y_foreground = librosa.istft(S_foreground * phase)
                y_background = librosa.istft(S_background * phase)

                # Alinierea și evaluarea
                reference_audio, estimated_audio = match_length(np.array([y, y]), np.array([y_foreground, y_background]))
                sdr, sir, sar, _ = mir_eval.separation.bss_eval_sources(reference_audio, estimated_audio)
                results.append((fft_size, overlap, margins, power, sdr.mean(), sir.mean(), sar.mean()))

# Afișarea rezultatelor
for result in results:
    print(f"FFT Size: {result[0]}, Overlap: {result[1]}, Margins: {result[2]}, Power: {result[3]}, SDR: {result[4]}, SIR: {result[5]}, SAR: {result[6]}")
# Out:
# Requirement already satisfied: mir_eval in /usr/local/lib/python3.10/dist-packages (0.7)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.25.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.11.4)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from mir_eval) (0.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.16.0)
# FFT Size: 512, Overlap: 0.25, Margins: (1, 5), Power: 1, SDR: 7.517081142193663, SIR: 159.1357147405071, SAR: 7.517081142102157
# FFT Size: 512, Overlap: 0.25, Margins: (1, 5), Power: 2, SDR: 5.089575070360893, SIR: 156.45727868957957, SAR: 5.089575070206778
# FFT Size: 512, Overlap: 0.25, Margins: (1, 5), Power: 3, SDR: 4.146672289425023, SIR: 155.73317585900625, SAR: 4.1466722892961
# FFT Size: 512, Overlap: 0.25, Margins: (2, 10), Power: 1, SDR: 5.581634614183726, SIR: 157.82589850667898, SAR: 5.581634614094224
# FFT Size: 512, Overlap: 0.25, Margins: (2, 10), Power: 2, SDR: 2.831391119514312, SIR: 154.9797636975466, SAR: 2.831391119549701
# FFT Size: 512, Overlap: 0.25, Margins: (2, 10), Power: 3, SDR: 1.947126875036198, SIR: 154.29506540706745, SAR: 1.9471268752750674
# FFT Size: 512, Overlap: 0.25, Margins: (3, 15), Power: 1, SDR: 4.451633688435646, SIR: 157.20416500679153, SAR: 4.451633688366622
# FFT Size: 512, Overlap: 0.25, Margins: (3, 15), Power: 2, SDR: 1.5062816101724046, SIR: 154.40625923998493, SAR: 1.5062816104053685
# FFT Size: 512, Overlap: 0.25, Margins: (3, 15), Power: 3, SDR: 0.6418005518757681, SIR: 153.81799634252877, SAR: 0.6418005523920742
# FFT Size: 512, Overlap: 0.5, Margins: (1, 5), Power: 1, SDR: -29.97885047550941, SIR: 164.69769241837378, SAR: -29.978850475720435
# FFT Size: 512, Overlap: 0.5, Margins: (1, 5), Power: 2, SDR: -30.920117008778018, SIR: 166.11801802663615, SAR: -30.920117008922304
# FFT Size: 512, Overlap: 0.5, Margins: (1, 5), Power: 3, SDR: -30.983563140161095, SIR: 165.99705127137247, SAR: -30.983563140309197
# FFT Size: 512, Overlap: 0.5, Margins: (2, 10), Power: 1, SDR: -30.328138888912342, SIR: 165.10739322715438, SAR: -30.32813888910615
# FFT Size: 512, Overlap: 0.5, Margins: (2, 10), Power: 2, SDR: -31.032587130264226, SIR: 166.71354762869998, SAR: -31.032587130379355
# FFT Size: 512, Overlap: 0.5, Margins: (2, 10), Power: 3, SDR: -31.126946299025395, SIR: 166.31680588892385, SAR: -31.12694629914332
# FFT Size: 512, Overlap: 0.5, Margins: (3, 15), Power: 1, SDR: -30.517723546412608, SIR: 165.4759283651913, SAR: -30.517723546591824
# FFT Size: 512, Overlap: 0.5, Margins: (3, 15), Power: 2, SDR: -31.122044836263747, SIR: 167.94464003290014, SAR: -31.122044836346888
# FFT Size: 512, Overlap: 0.5, Margins: (3, 15), Power: 3, SDR: -31.193600334910926, SIR: 168.4663234530667, SAR: -31.193600334975496
# FFT Size: 1024, Overlap: 0.25, Margins: (1, 5), Power: 1, SDR: 6.731884409041259, SIR: 160.07095354287134, SAR: 6.731884408928349
# FFT Size: 1024, Overlap: 0.25, Margins: (1, 5), Power: 2, SDR: 4.663064119781052, SIR: 158.2019137014194, SAR: 4.663064119592669
# FFT Size: 1024, Overlap: 0.25, Margins: (1, 5), Power: 3, SDR: 3.9236039644667873, SIR: 157.76869131216404, SAR: 3.9236039642764933
# FFT Size: 1024, Overlap: 0.25, Margins: (2, 10), Power: 1, SDR: 5.077138616604526, SIR: 158.83424808552712, SAR: 5.077138616470217
# FFT Size: 1024, Overlap: 0.25, Margins: (2, 10), Power: 2, SDR: 2.7895342825954974, SIR: 156.70389271162873, SAR: 2.7895342824231966
# FFT Size: 1024, Overlap: 0.25, Margins: (2, 10), Power: 3, SDR: 2.0349455161952728, SIR: 156.15774982119126, SAR: 2.0349455160514043
# FFT Size: 1024, Overlap: 0.25, Margins: (3, 15), Power: 1, SDR: 4.092473965032556, SIR: 158.27187056484297, SAR: 4.092473964889326
# FFT Size: 1024, Overlap: 0.25, Margins: (3, 15), Power: 2, SDR: 1.6306932719690166, SIR: 156.00500482314385, SAR: 1.630693271840164
# FFT Size: 1024, Overlap: 0.25, Margins: (3, 15), Power: 3, SDR: 0.8634472405988887, SIR: 155.44646050375957, SAR: 0.8634472405165048
# FFT Size: 1024, Overlap: 0.5, Margins: (1, 5), Power: 1, SDR: -33.25728760648154, SIR: 166.19438579274362, SAR: -33.25728760645691
# FFT Size: 1024, Overlap: 0.5, Margins: (1, 5), Power: 2, SDR: -33.02258204051067, SIR: 165.18811677746865, SAR: -33.022582040414584
# FFT Size: 1024, Overlap: 0.5, Margins: (1, 5), Power: 3, SDR: -32.97989410761333, SIR: 165.18550622536523, SAR: -32.979894107548134
# FFT Size: 1024, Overlap: 0.5, Margins: (2, 10), Power: 1, SDR: -32.90487054484466, SIR: 166.8899370806364, SAR: -32.90487054475781
# FFT Size: 1024, Overlap: 0.5, Margins: (2, 10), Power: 2, SDR: -32.68357800288471, SIR: 166.33632165013694, SAR: -32.68357800276439
# FFT Size: 1024, Overlap: 0.5, Margins: (2, 10), Power: 3, SDR: -32.71608707719072, SIR: 166.36178618557028, SAR: -32.71608707709564
# FFT Size: 1024, Overlap: 0.5, Margins: (3, 15), Power: 1, SDR: -32.739420563128036, SIR: 167.60739699857442, SAR: -32.7394205630081
# FFT Size: 1024, Overlap: 0.5, Margins: (3, 15), Power: 2, SDR: -32.65754107258191, SIR: 167.39303578738992, SAR: -32.65754107243494
# FFT Size: 1024, Overlap: 0.5, Margins: (3, 15), Power: 3, SDR: -32.79442237190732, SIR: 167.50462270061564, SAR: -32.794422371767354
# FFT Size: 2048, Overlap: 0.25, Margins: (1, 5), Power: 1, SDR: 6.823863645567267, SIR: 161.0787807792282, SAR: 6.823863645444139
# FFT Size: 2048, Overlap: 0.25, Margins: (1, 5), Power: 2, SDR: 4.9365878603996975, SIR: 159.3884598579066, SAR: 4.936587860220321
# FFT Size: 2048, Overlap: 0.25, Margins: (1, 5), Power: 3, SDR: 4.280207845441967, SIR: 159.0512187949273, SAR: 4.280207845257896
# FFT Size: 2048, Overlap: 0.25, Margins: (2, 10), Power: 1, SDR: 5.284016476415332, SIR: 160.12587364354414, SAR: 5.28401647627457
# FFT Size: 2048, Overlap: 0.25, Margins: (2, 10), Power: 2, SDR: 3.2248547706277884, SIR: 158.3995744629569, SAR: 3.224854770446811
# FFT Size: 2048, Overlap: 0.25, Margins: (2, 10), Power: 3, SDR: 2.5653820861781433, SIR: 158.05763412557076, SAR: 2.565382086009185
# FFT Size: 2048, Overlap: 0.25, Margins: (3, 15), Power: 1, SDR: 4.344227946187762, SIR: 159.69688709508225, SAR: 4.344227946036048
# FFT Size: 2048, Overlap: 0.25, Margins: (3, 15), Power: 2, SDR: 2.0186343074548123, SIR: 157.947016566508, SAR: 2.018634307281307
# FFT Size: 2048, Overlap: 0.25, Margins: (3, 15), Power: 3, SDR: 1.2294452110649754, SIR: 157.52408920453468, SAR: 1.2294452109085192
# FFT Size: 2048, Overlap: 0.5, Margins: (1, 5), Power: 1, SDR: -39.42577385917613, SIR: 169.7566593826228, SAR: -39.42577385928508
# FFT Size: 2048, Overlap: 0.5, Margins: (1, 5), Power: 2, SDR: -39.34441680686352, SIR: 171.59078636525683, SAR: -39.344416806994346
# FFT Size: 2048, Overlap: 0.5, Margins: (1, 5), Power: 3, SDR: -39.368599117584154, SIR: 174.14329322713468, SAR: -39.36859911770938
# FFT Size: 2048, Overlap: 0.5, Margins: (2, 10), Power: 1, SDR: -39.096096497285785, SIR: 169.6665607291916, SAR: -39.096096497387435
# FFT Size: 2048, Overlap: 0.5, Margins: (2, 10), Power: 2, SDR: -38.92539806372774, SIR: 169.72320952899798, SAR: -38.92539806380945
# FFT Size: 2048, Overlap: 0.5, Margins: (2, 10), Power: 3, SDR: -38.79145825284321, SIR: 169.6810993241873, SAR: -38.79145825291139
# FFT Size: 2048, Overlap: 0.5, Margins: (3, 15), Power: 1, SDR: -38.84987272904106, SIR: 170.5929548003673, SAR: -38.84987272913065
# FFT Size: 2048, Overlap: 0.5, Margins: (3, 15), Power: 2, SDR: -38.636032036466155, SIR: 170.5642168336626, SAR: -38.636032036521314
# FFT Size: 2048, Overlap: 0.5, Margins: (3, 15), Power: 3, SDR: -38.499996141748014, SIR: 171.75162263437232, SAR: -38.499996141793616
